// %%
/*(base) jovyan@878d4c863110:~/work/Lectures$ cd ..
(base) jovyan@878d4c863110:~/work$ cd ..
(base) jovyan@878d4c863110:~$ cd public/LEC001/hello
bash: cd: public/LEC001/hello: No such file or directory
(base) jovyan@878d4c863110:~$ cd hello.txt
bash: cd: hello.txt: No such file or directory
(base) jovyan@878d4c863110:~$ cd public
(base) jovyan@878d4c863110:~/public$ cd LEC001
(base) jovyan@878d4c863110:~/public/LEC001$ cd Lecture 6a
bash: cd: too many arguments
(base) jovyan@878d4c863110:~/public/LEC001$ cd "Lecture 6a"
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$ cd ..
(base) jovyan@878d4c863110:~/public/LEC001$ cd ..
(base) jovyan@878d4c863110:~/public$ cd ..
(base) jovyan@878d4c863110:~$ cd work
(base) jovyan@878d4c863110:~/work$ cd Lectures
(base) jovyan@878d4c863110:~/work/Lectures$ cd ..
(base) jovyan@878d4c863110:~/work$ cd ..
(base) jovyan@878d4c863110:~$ ls
public  work
(base) jovyan@878d4c863110:~$ cd public
(base) jovyan@878d4c863110:~/public$ ld
ld: no input files
(base) jovyan@878d4c863110:~/public$ ls
labs  LEC001  LEC006  LEC013  Notes  videos
(base) jovyan@878d4c863110:~/public$ cd LEC001
(base) jovyan@878d4c863110:~/public/LEC001$ ls
'Lecture 1a'  'Lecture 1b'  'Lecture 2a'  'Lecture 2b'  'Lecture 3a'  'Lecture 3b'  'Lecture 4a'  'Lecture 4b'  'Lecture 5a'  'Lecture 6a'
(base) jovyan@878d4c863110:~/public/LEC001$ cd 'Lecture 6a'
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$
(base) jovyan@878d4c863110:~$ cd public/LEC001/Lecture\ 6a
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$ cd ../../..
(base) jovyan@878d4c863110:~$ */

// %%
/*
(base) jovyan@878d4c863110:~/work/Lectures$ mkdir 6aExercise2
(base) jovyan@878d4c863110:~/work/Lectures$ touch 6a
(base) jovyan@878d4c863110:~/work/Lectures$ mv 6a to 6aExercise2
mv: cannot stat 'to': No such file or directory
(base) jovyan@878d4c863110:~/work/Lectures$ mv 6a 6aExercise2
mv: cannot stat '6a': No such file or directory
(base) jovyan@878d4c863110:~/work/Lectures$ touch 6a
(base) jovyan@878d4c863110:~/work/Lectures$ mv 6a 6aExercise2
(base) jovyan@878d4c863110:~/work/Lectures$ cd 6aExercise2
(base) jovyan@878d4c863110:~/work/Lectures/6aExercise2$ ls
6a
(base) jovyan@878d4c863110:~/work/Lectures/6aExercise2$ cd ../../..
(base) jovyan@878d4c863110:~$ cd public/LEC001/Lecture\ 6a
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$ ls
hello.txt  somestuff  test.txt
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$ cp test.txt ~
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$ ../../..
bash: ../../..: Is a directory
(base) jovyan@878d4c863110:~/public/LEC001/Lecture 6a$ cd ../../..
(base) jovyan@878d4c863110:~$ ls
public  test.txt  work
(base) jovyan@878d4c863110:~$ rm test.txt
(base) jovyan@878d4c863110:~$ ls
public  work
(base) jovyan@878d4c863110:~$ 
*/

// %%
/*
(base) jovyan@058f1b343f1f:~$ touch textfile.txt
(base) jovyan@058f1b343f1f:~$ ls
public  textfile.txt  work
(base) jovyan@058f1b343f1f:~$ ls -l
total 8
drwxr-xr-x 9 jovyan users 4096 Sep 26 10:59 public
-rw-r--r-- 1 jovyan users    0 Oct 19 11:09 textfile.txt
drwxr-xr-x 6 jovyan users 4096 Sep 10 14:33 work
(base) jovyan@058f1b343f1f:~$ chmod 666 textfile.txt
(base) jovyan@058f1b343f1f:~$ ls -l
total 8
drwxr-xr-x 9 jovyan users 4096 Sep 26 10:59 public
-rw-rw-rw- 1 jovyan users    0 Oct 19 11:09 textfile.txt
drwxr-xr-x 6 jovyan users 4096 Sep 10 14:33 work
(base) jovyan@058f1b343f1f:~$ chmod 644 textfile.txt
(base) jovyan@058f1b343f1f:~$ ls -l
total 8
drwxr-xr-x 9 jovyan users 4096 Sep 26 10:59 public
-rw-r--r-- 1 jovyan users    0 Oct 19 11:09 textfile.txt
drwxr-xr-x 6 jovyan users 4096 Sep 10 14:33 work
(base) jovyan@058f1b343f1f:~$ 

(base) jovyan@058f1b343f1f:~$ find -name "2b Looping.ipynb"
./work/Lectures/2b Looping.ipynb
(base) jovyan@058f1b343f1f:~$ whereis "2b loopin"
*/
