# %%
# Load a CSV file into a Pandas DataFrame, display the first five rows, and show basic information about the dataset.
import pandas as pd
df = pd.read_csv('imdb_movie_dataset.csv')
print(df.head())
print(df.info())
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
# Filter the rows of a DataFrame where the values in the Age column are greater than 30.
filtered_df = df[df['Rating'] > 8]
print(filtered_df)
# Out:
#      Rank                                         Title  \
# 0       1                       Guardians of the Galaxy
# 6       7                                    La La Land
# 16     17                                 Hacksaw Ridge
# 18     19                                          Lion
# 26     27                       Bahubali: The Beginning
# 36     37                                  Interstellar
# 50     51    Star Wars: Episode VII - The Force Awakens
# 54     55                               The Dark Knight
# 64     65                                  The Prestige
# 67     68                            Mad Max: Fury Road
# 74     75                                      Zootopia
# 76     77                                  The Avengers
# 77     78                          Inglourious Basterds
# 80     81                                     Inception
# 82     83                       The Wolf of Wall Street
# 83     84                                     Gone Girl
# ...

# %%
# Calculate the mean, median, and standard deviation for each numerical column in the dataset.

# %%
# Select the columns Name, Age, and Salary from the DataFrame

# %%
# Filter rows where Age is greater than 25 and Salary is greater than 50000

# %%
# Calculate a 10% bonus on the Salary and add it as a new column called Bonus.

# %%
#Using loc, select rows with indices 0 to 3 and columns Name and Age.

# %%
# Using loc, select rows where Age is greater than 30 and display the Name and Salary columns.

# %%
# Set the Status column to 'Senior' for employees with an Age greater than 40.

# %%
# Using iloc, select the first 5 rows and the first 3 columns.

# %%
# Select rows with indices 1, 3, and 5 and columns with indices 0, 2, and 4 using iloc.

# %%
# Select rows 5 to 10 and columns 2 to 4 using iloc.

# %%
# The DataFrame has a Price column. 
# Add a new column called Discounted_Price, which applies a 10% discount to Price if the price is above 100, otherwise keep it the same. 
# Use the apply() function.
